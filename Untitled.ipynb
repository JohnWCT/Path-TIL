# %%
import keras
# Out:
# 2026-04-14 07:00:32.349953: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pretrained_path = './best_InceptionResNetV2_model.h5'

# %%
model = keras.models.load_model(pretrained_path, compile=False)
ly = model.layers
# Out:
# 2026-04-14 07:00:53.436696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-04-14 07:00:53.442903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-04-14 07:00:53.444939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-04-14 07:00:53.447151: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# ...

# %%
ly

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  inception_resnet_v2 (Functi  (None, 1536)             54336736
#  onal)
#
#  flatten_8 (Flatten)         (None, 1536)              0
#
#  dense_16 (Dense)            (None, 512)               786944
#
#  dense_17 (Dense)            (None, 3)                 1539
#
# ...
# Total params: 55,125,219
# Trainable params: 788,483
# Non-trainable params: 54,336,736
# _________________________________________________________________
